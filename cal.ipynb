# %%
nums = [288, 20, 11, 9, 5]

print(sum(nums))
print("---")
for i in nums:
    print(round( i / 333, 3) * 100)
# Out:
# 333
# ---
# 86.5
# 6.0
# 3.3000000000000003
# 2.7
# 1.5

# %%
(76.5+86.7+81.3+68.4) / 4
# Out:
# 78.225
